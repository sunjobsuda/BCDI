# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score
from sklearn.feature_selection import VarianceThreshold
import lightgbm as lgb
import warnings
from sklearn.preprocessing import OneHotEncoder
import zipfile
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
warnings.filterwarnings('ignore')
n_splits = 5
seed = 42
path = 'E:/BDCI Match/'

#文件路径

traindataFile = path + 'train_preproceed.csv'
testdataFile = path+ 'test.csv'

#文件加载
train = pd.read_csv(traindataFile)
test = pd.read_csv(testdataFile)

#current_service为99104722的记录可以剔除，因为service_type=3 <=> current_service=99104722
train1 = train.loc[train['service_type']==1]
train2 = train.loc[train['service_type']==4]

# 对标签编码 映射关系
label2current_service1 = dict(zip(range(0,len(set(train1['current_service']))),sorted(list(set(train1['current_service'])))))
current_service2label1 = dict(zip(sorted(list(set(train1['current_service']))),range(0,len(set(train1['current_service'])))))

label2current_service2 = dict(zip(range(0,len(set(train2['current_service']))),sorted(list(set(train2['current_service'])))))
current_service2label2 = dict(zip(sorted(list(set(train2['current_service']))),range(0,len(set(train2['current_service'])))))

# 原始数据的标签映射
train1['current_service'] = train1['current_service'].map(current_service2label1)
train2['current_service'] = train2['current_service'].map(current_service2label2)

# 构造原始数据
y1 = train1.pop('current_service')
train_id1 = train1.pop('user_id')
# 这个字段有点问题
X1 = train1
train_col = train1.columns

# 构造原始数据
y2 = train2.pop('current_service')
train_id2 = train2.pop('user_id')
# 这个字段有点问题
X2 = train2
train_col = train2.columns

# X_test = test[train_col]
# test_id = test['user_id']

# 数据有问题数据
for i in train_col:
    X1[i] = X1[i].replace("\\N",-1)
    X2[i] = X2[i].replace("\\N",-1)

#X1,y1,X2,y2 = X1.values,y1,X2.values,y2

print(current_service2label1)
print(current_service2label2)
# Out:
# {90063345: 0, 90109916: 1, 90155946: 2}
# {89016252: 0, 89016253: 1, 89016259: 2, 89950166: 3, 89950167: 4, 89950168: 5, 99999825: 6, 99999826: 7, 99999827: 8, 99999828: 9, 99999830: 10}

# %%
X1['average_fee'] = X1['1_total_fee']+X1['2_total_fee']+X1['3_total_fee']+X1['4_total_fee']
sns.boxplot(x=y1, y=X1['average_fee'])

# %%
sns.set(rc={'figure.figsize':(10,5)})
sns.boxplot(x=y1, y=X1['is_mix_service'])

# %%
sns.boxplot(x=y1, y=X1['online_time'])

# %%
sns.boxplot(x=y1, y=X1['1_total_fee'])

# %%
sns.boxplot(x=y1, y=X1['2_total_fee'])

# %%
sns.boxplot(x=y1, y=X1['3_total_fee'])

# %%
sns.boxplot(x=y1, y=X1['4_total_fee'])

# %%
sns.boxplot(x=y1, y=X1['month_traffic'])

# %%
sns.boxplot(x=y1, y=X1['many_over_bill'])

# %%
sns.boxplot(x=y1, y=X1['contract_type'])

# %%
sns.boxplot(x=y1, y=X1['contract_time'])

# %%
sns.boxplot(x=y1, y=X1['is_promise_low_consume'])

# %%
# sns.set(style="whitegrid", color_codes=True)
# np.random.seed(sum(map(ord, "categorical")))
# tips = sns.load_dataset("tips")
# titanic = sns.load_dataset("titanic")
# iris = sns.load_dataset("iris")
# # 图形组合也就是两条绘图语句一起运行就可以了，相当于图形覆盖了
# sns.boxplot(x=tips["day"], y=tips["total_bill"])
# sns.swarmplot(x="day", y="total_bill", data=tips, color=".25")
# plt.show()

sns.boxplot(x=y1, y=X1['net_service'])
#sns.swarmplot(x='service_type', y='net_service',data = X1[0:500])
#plt.show()

# %%
sns.boxplot(x=y1, y=X1['pay_times'])

# %%
sns.boxplot(x=y1, y=X1['pay_num'])

# %%
X1['pay'] = X1['pay_num']*X1['pay_times']
sns.boxplot(x=y1, y=X1['pay'])

# %%
X1['pay'] = X1['pay_num']/X1['pay_times']
sns.boxplot(x=y1, y=X1['pay'])

# %%
sns.boxplot(x=y1, y=X1['last_month_traffic'])

# %%
sns.boxplot(x=y1, y=X1['local_trafffic_month'])

# %%
X1['traffic'] = X1['local_trafffic_month']/X1['last_month_traffic']
sns.boxplot(x=y1, y=X1['traffic'])

# %%
sns.boxplot(x=y1, y=X1['local_caller_time'])

# %%
sns.boxplot(x=y1, y=X1['service1_caller_time'])

# %%
sns.boxplot(x=y1, y=X1['service2_caller_time'])

# %%
X1['caller_time'] = X1['service2_caller_time']+X1['last_month_traffic']
sns.boxplot(x=y1, y=X1['traffic'])

# %%
sns.boxplot(x=y, y=train['service_type'])

# %%
sns.set(rc={'figure.figsize':(20,10)})
sns.countplot(x =train['service_type'],hue = y)

# %%
sns.boxplot(x=y, y=train['is_mix_service'])

# %%
sns.boxplot(x=y, y=train['online_time'])

# %%
sns.boxplot(x=y, y=train['1_total_fee'])

# %%
sns.boxplot(x=y, y=train['2_total_fee'])

# %%
sns.boxplot(x=y, y=train['3_total_fee'])

# %%
sns.boxplot(x=y, y=train['4_total_fee'])

# %%
sns.boxplot(x=y, y=train['month_traffic'])

# %%
sns.boxplot(x=y, y=train['many_over_bill'])

# %%
sns.boxplot(x=y, y=train['contract_type'])

# %%
sns.boxplot(x=y, y=train['contract_time'])

# %%
sns.boxplot(x=y, y=train['is_promise_low_consume'])

# %%
sns.boxplot(x=y, y= train['net_service'])

# %%
sns.boxplot(x=y, y=train['last_month_traffic'])

# %%
sns.boxplot(x=train.loc[train['service_type']==3]['service_type'], y=y)

# %%
sns.boxplot(x=train.loc[train['last_month_traffic']>18000]['service_type'], y=y)

# %%
sns.boxplot(x=y, y=train['pay_times'])

# %%
sns.boxplot(x=y, y=train['pay_num'])

# %%
sns.boxplot(x=y, y=train['local_trafffic_month'])

# %%
sns.boxplot(x=y, y=train['local_caller_time'])

# %%
sns.boxplot(x=y, y=train['service1_caller_time'])

# %%
sns.boxplot(x=y, y=train['service2_caller_time'])

# %%
sns.boxplot(x=y, y=train['age'])

# %%
sns.boxplot(x=y, y=train['former_complaint_num'])

# %%
sns.boxplot(x=y, y=train['former_complaint_fee'])
